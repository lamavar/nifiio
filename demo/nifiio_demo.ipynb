# %%
from nii_local import NiiLocalDemo

# %%
niil = NiiLocalDemo()
result = niil.get_stocklist_with_weights(index_name='NIFTY 100', write_to_file=False, file_types=['json', 'csv'], write_to_file_path='C:/nifiio/files/')
# print(result)
for stock in result:
    stock.
# Out:
# Reading csv file:  D:/Dev/GitRepos/stocks_mf_apps/niftyindicesinfo_local/files/input_files/ind_nifty100list.csv
# File path:  D:/Dev/GitRepos/stocks_mf_apps/niftyindicesinfo_local/files/input_files/SectorialIndexDataNIFTY 100.js
# Weight for ABB is 0.13
# Weight for ACC is 0.24
# Weight for ADANIPORTS is 0.52
# Weight for ABCAPITAL is 0.11
# Weight for AMBUJACEM is 0.31
# Weight for ASHOKLEY is 0.25
# Weight for ASIANPAINT is 1.28
# Weight for AUROPHARMA is 0.4
# Weight for DMART is 0.31
# Weight for AXISBANK is 2.54
# Weight for BAJAJ-AUTO is 0.8
# Weight for BAJFINANCE is 1.27
# Weight for BAJAJFINSV is 0.79
# Weight for BANDHANBNK is 0.12
# Weight for BANKBARODA is 0.19
# Weight for BEL is 0.15
# Weight for BHEL is 0.17
# Weight for BPCL is 0.55
# Weight for BHARTIARTL is 0.85
# Weight for INFRATEL is 0.5
# Weight for BIOCON is 0.26
# Weight for BOSCHLTD is 0.35
# Weight for BRITANNIA is 0.73
# Weight for CADILAHC is 0.16
# Weight for CIPLA is 0.57
# Weight for COALINDIA is 0.77
# ...

# %%
import os
write_to_file_path='C:/nifiio/files/'
os.makedirs(write_to_file_path)
